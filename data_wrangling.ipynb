# %%
import pandas as pd

# %%
mk2 = pd.read_excel("data.xlsx", sheet_name="MK2")

# %%
mk2
# Out:
#     Year  kW/Cabinet  Installed Cabinets  Average PUE  Total load (MW)  \
# 0   2025    4.902500                 600        1.496         4.400484
# 1   2026    5.362250                1200        1.492        10.423709
# 2   2027    5.945621                1800        1.488        18.112251
# 3   2028    6.558234                2400        1.484        27.523224
# 4   2029    6.738455                2400        1.480        28.416000
# 5   2030    6.896148                2400        1.476        28.339200
# 6   2031    7.034130                2400        1.472        28.262400
# 7   2032    7.154864                2400        1.468        28.185600
# 8   2033    7.260506                2400        1.464        28.108800
# 9   2034    7.352942                2400        1.460        28.032000
# 10  2035    7.433825                2400        1.460        28.032000
# 11  2036    7.504597                2400        1.460        28.032000
# ...

# %%
mk2 = read_data("data.xlsx", "MK2")
mk2m = read_data("data.xlsx", "MK2 Modified")

# %%
kw_cab_df = mk2[['kW/Cabinet']].join(mk2m[['kW/Cabinet']], lsuffix="_mk2", rsuffix="_mk2m")

# %%
kw_cab_df
# Out:
# Year of Life   kW/Cabinet_mk2  kW/Cabinet_mk2m
# Calendar Year
# 2025                 4.902500         6.885000
# 2026                 5.362250         7.767500
# 2027                 5.945621         8.945625
# 2028                 6.558234        10.243066
# 2029                 6.738455        10.840808
# 2030                 6.896148        11.674457
# 2031                 7.034130        12.737025
# 2032                 7.154864        14.022397
# 2033                 7.260506        15.474597
# 2034                 7.352942        17.102773
# 2035                 7.433825        18.714926
# 2036                 7.504597        20.313060
# 2037                 7.566522        21.898928
# 2038                 7.620707        23.474062
# 2039                 7.668118        25.039804
# 2040                 7.709604        26.597329
# 2041                 7.745903        28.147662
# 2042                 7.777665        29.629205
# 2043                 7.805457        30.925554
# ...
